# %% [markdown]
# <a href="https://colab.research.google.com/github/Julienader/Julienader/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd


csv_file = list(uploaded.keys())[0]
df = pd.read_csv(csv_file)


print("✅ Patient data loaded successfully.")
print(f"Total records: {len(df)}")


print("\n👀 Sample patient data:")
print(df.head())

print("\n🧓 Patients older than 40:")
older_patients = df[df['Age'] > 40]
print(older_patients)

print("\n📊 Diagnosis distribution:")
print(df['Diagnosis'].value_counts())

filtered_file_name = "patients_above_40.csv"
older_patients.to_csv(filtered_file_name, index=False)
print(f"\n💾 Filtered data saved as: {filtered_file_name}")
# Out:
#      <input type="file" id="files-31b5f850-f440-4df7-8385-7cb7354b7012" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31b5f850-f440-4df7-8385-7cb7354b7012">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()


import pandas as pd
import matplotlib.pyplot as plt




csv_file = list(uploaded.keys())[0]
df = pd.read_csv(csv_file)
=
print("✅ Loaded data successfully.")
print(f"Total records: {len(df)}\n")
print(df.head())


plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], bins=10, kde=True)
plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Number of Patients')
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Gender')
plt.title('Patient Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Diagnosis', order=df['Diagnosis'].value_counts().index)
plt.title('Diagnosis Frequency')
plt.xticks(rotation=45)
plt.xlabel('Diagnosis')
plt.ylabel('Number of Patients')
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Diagnosis', y='Age')
plt.title('Age Distribution by Diagnosis')
plt.xticks(rotation=45)
plt.xlabel('Diagnosis')
plt.ylabel('Age')
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
sns.heatmap(df.select_dtypes(include=['int', 'float']).corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-93b7025b-940f-46ad-b9e3-7e54beef9629" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93b7025b-940f-46ad-b9e3-7e54beef9629">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
